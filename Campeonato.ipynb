# %%
import random
Equipos=['Brasil','Argentina','Colombia','Chile','Ecuador','Peru']
Brasil={1:'Gomez', 10:'Triana', 15:'Fernandez', 2:'Palacio', 8: 'Miranda',7: 'Montero',9: 'Benito',3: 'Pinzon',4:'Rueda', 11: 'Hernandez', 5:'Vasco', 12:'Alfonso', 19:'Alvarez', 17:'Batanero', 16: 'Montaño', 23:'Rodriguez', 18:'Vargas'}
Argentina={1:'Ramirez',10: 'Messi',29: 'Gutierrez',24: 'Rodriguez',4: 'Matiz',5: 'Bernal', 12:'Escobar', 25:'Valderrama',45:'Velez', 11:'Lozano',21:'Atehortua',90: 'Torres',16: 'Lopez',9: 'Pedraza', 14:'Bonilla', 56:'Triviño',44:'Sacristan' }
Colombia={1:'Rodriguez',23: 'Ospina',11: 'Diaz',9: 'Sanchez',7: 'Cuadrado',10:'Uribe',16: 'Mina', 21:'Triana',19:'Fernandez', 22:'Ramirez', 34:'Matiz',4: 'Miranda', 3:'Escobar', 17:'Valderrama', 2:'cubidez',6:'Ortega', 56:'Olaya'}
Chile={1:'Iniesta', 33:'Hernandez',7: 'Busquest', 9:'Ramos',11: 'Ronaldo',10: 'Alexis',21: 'Vidal', 19:'Vargas',22:'Bravo',66:'Valdivia', 101:'Jarrasco', 49:'Alvarez', 2:'Estupiñan',5: 'Cardona', 17:'Musleda', 77:'Garrincha',18:'Khan'}
Ecuador={ 1:'Llanos',15: 'Lloris',6: 'Kante',7: 'Pogba',9: 'Mbappe',11: 'Kounde', 10:'Pique', 33:'Torres',19: 'Acosta',43:'Carrion',15: 'Bernal', 88:'Di Maria', 23:'Haland', 54:'Cortes', 8:'Carpintero', 3:'Rengifo',41:'Virguez'}
Peru={1:'Miranda',7: 'Uribe',9: 'Quijano',11: 'Valencia',10: 'Zarama',19: 'Acero',21: 'Bonilla',8: 'Olaya',66:'Ramos',22:'Rosales',33: 'Sanchez', 17:'Gonzalez',18: 'Dybala',5: 'Ferrar',2: 'Matiz', 4:'Triana', 77:'Montero'}
Posiciones=['Portero', 'Defensa', 'Defensa', 'Defensa', 'Defensa', 'Delantero', 'Delantero','Delantero', 'Mediocampista', 'Mediocampista', 'Mediocampista', 'Suplentes','Suplentes', 'Suplentes','Suplentes', 'Suplentes', 'Suplentes']
print (Equipos)
print('----------------------------------------------------------')
#Jugadores de Brasil
for Numeros in Brasil:
  print(f'Jugador de Brasil:', Numeros,':',Brasil[Numeros])
print()
#Jugadores de Argentina
for Numeros in Argentina:
  print(f'Jugador de Argentina:',Numeros,':',Argentina[Numeros])
print()
#Jugadores de Colombia
for Numeros in Colombia:
  print(f'Jugador de Colombia:',Numeros,':',Colombia[Numeros])
print()
#Jugadores de Chile
for Numeros in Chile:
  print(f'Jugador de Chile:',Numeros,':',Chile[Numeros])
print()
#Jugadores de Ecuador
for Numeros in Ecuador:
  print(f'Jugador de Ecuador:',Numeros,':',Ecuador[Numeros])
print()
#Jugadores de Peru
for Numeros in Peru:
  print(f'Jugadores de Peru:',Numeros,':',Peru[Numeros])
print()
print('----------------------------------------------------------')
#Posiciones de Jugadores de Brasil
for Numeros,Posicion in enumerate (Brasil):
  print(f'Posición de jugador de Brasil:',Posicion,':',Posiciones[Numeros])
print()
#Posiciones de Jugadores de Argentina
for Numeros,Posicion in enumerate (Argentina):
  print(f'Posición de jugador de Argentina:',Posicion,':',Posiciones[Numeros])
print()
#Posiciones de Jugadores de Colombia
for Numeros,Posicion in enumerate (Colombia):
  print(f'Posición de jugador de Colombia:',Posicion,':',Posiciones[Numeros])
print()
#Posiciones de Jugadores de Chile
for Numeros,Posicion in enumerate (Chile):
  print(f'Posición de jugador de Chile:',Posicion,':',Posiciones[Numeros])
print()
#Posiciones de Jugadores de Ecuador
for Numeros,Posicion in enumerate (Ecuador):
  print(f'Posición de jugador de Ecuador:',Posicion,':',Posiciones[Numeros])
print()
#Posiciones de Jugadores de Peru
for Numeros,Posicion in enumerate (Peru):
  print(f'Posición de jugador de Peru:',Posicion,':',Posiciones[Numeros])
print()
print('----------------------------------------------------------')
#Añadir un jugador de Brasil
Cambio={27:'Gonzalez'}
Brasil.update(Cambio)
Brasil.pop(3)
for Numeros,Jugador in Brasil.items():
  print(f'Jugador Nueva convocatoria de Brasil',Numeros,':',Jugador)
print()
#Añadir un jugador de Argentina
Cambio1={90:'Palacio'}
Argentina.update(Cambio1)
#Argentina.pop(3)
for Numeros,Jugador in Argentina.items():
  print(f'Jugador Nueva convocatoria de Argentina',Numeros,':',Jugador)
print()
#Añadir un jugador de Colombia
Cambio2={105:'Jones'}
Colombia.update(Cambio2)
Colombia.pop(11)
for Numeros,Jugador in Colombia.items():
  print(f'Jugador Nueva convocatoria de Colombia',Numeros,':',Jugador)
print()
#Añadir un jugador de Chile
Cambio3={96:'Miranda'}
Chile.update(Cambio3)
#Chile.pop(8)
for Numeros,Jugador in Chile.items():
  print(f'Jugador Nueva convocatoria de Chile',Numeros,':',Jugador)
print()
#Añadir un jugador de Ecuador
Cambio4={89:'Serrato'}
Ecuador.update(Cambio4)
#Ecuador.pop(5)
for Numeros,Jugador in Ecuador.items():
  print(f'Jugador Nueva convocatoria de Ecuador',Numeros,':',Jugador)
print()
#Añadir un jugador de Peru
Cambio5={48:'Perez'}
Peru.update(Cambio5)
Peru.pop(11)
for Numeros,Jugador in Peru.items():
  print(f'Jugador Nueva convocatoria de Peru',Numeros,':',Jugador)
print()
print('----------------------------------------------------------')
#Capitanes de cada equipo
print('Capitan de Brasil es:')
print (Brasil[1])
print('Capitan de Argentina es:')
print (Argentina[10])
print('Capitan de Colombia es:')
print (Colombia[10])
print('Capitan de Chile es:')
print (Chile[7])
print('Capitan de Ecuador es:')
print (Ecuador[10])
print('Capitan de Peru es:')
print (Peru[10])
print('----------------------------------------------------------')
#Lista de partidos y resultados
def realizar_partido():
    goles1 = random.choice(range(0,5))
    goles2 = random.choice(range(0,5))
    if goles1 > goles2:
        puntos1 = 3
        puntos2 = 0
    elif goles1 < goles2:
        puntos1 = 0
        puntos2 = 3
    else:
        puntos1 = 1
        puntos2 = 1
     
    return [(puntos1, goles1, goles2), (puntos2, goles2, goles1)]

def jugar_calendario(partidos):
    resultados = {}
    for ronda, matches in partidos.items():
        print("========== {} ==========".format(ronda))
        for match in matches:
            grupo = match[0]
            pais1 = match[1]
            pais2 = match[2]
            r = realizar_partido()
            print("{} -> {} {} - {} {}".format(grupo, pais1, r[0][1], r[1][1], pais2))
            # Guardar los resultados en otro diccionario
            if pais1 not in resultados:
                resultados[pais1] = [r[0]]
                resultados[pais2] = [r[1]]
            else:
                resultados[pais1].append(r[0])
                resultados[pais2].append(r[1])
        print()
    return resultados

def crear_calendario(equipos):
    todos_partidos = {}
    for grupo, paises in equipos.items():
        
        ronda1 = [(grupo, paises[0], paises[1]), (grupo, paises[2], paises[3])]
        ronda2 = [(grupo, paises[1], paises[2]), (grupo, paises[3], paises[0])]
        ronda3 = [(grupo, paises[0], paises[2]), (grupo, paises[3], paises[1])]
        
        if 'Ronda 1' not in todos_partidos:
            
            todos_partidos['Ronda 1'] = [ronda1[0], ronda1[1]]
            todos_partidos['Ronda 2'] = [ronda2[0], ronda2[1]]
            todos_partidos['Ronda 3'] = [ronda3[0], ronda3[1]]
        else:
            
            todos_partidos['Ronda 1'].extend([ronda1[0], ronda1[1]])
            todos_partidos['Ronda 2'].extend([ronda2[0], ronda2[1]])
            todos_partidos['Ronda 3'].extend([ronda3[0], ronda3[1]])
    return todos_partidos

#Tabulación de los resultados de cada equipo
equipos = {\
'GRUPO A':['Argentina', 'Chile', 'Colombia', 'Equipo invitado'], \
'GRUPO B':['Brasil', 'Peru', 'Ecuador', 'Equipo inivitado']}

calendario = crear_calendario(equipos)
tabla_resultados = jugar_calendario(calendario)
#imprimir los resultados de goles por pais
print("========== RESULTADOS ==========")

for pais, resultados in tabla_resultados.items():
    pais = pais.ljust(12, ' ') 
    puntos = 0
    GF = 0
    GC = 0
    for values in resultados:
        puntos += values[0]
        GF += values[1]
        GC += values[2]
    print("{} -> PTS: {} | GF: {} | GC: {}".format(pais, puntos, GF, GC))
# Out:
# ['Brasil', 'Argentina', 'Colombia', 'Chile', 'Ecuador', 'Peru']
# ----------------------------------------------------------
# Jugador de Brasil: 1 : Gomez
# Jugador de Brasil: 10 : Triana
# Jugador de Brasil: 15 : Fernandez
# Jugador de Brasil: 2 : Palacio
# Jugador de Brasil: 8 : Miranda
# Jugador de Brasil: 7 : Montero
# Jugador de Brasil: 9 : Benito
# Jugador de Brasil: 3 : Pinzon
# Jugador de Brasil: 4 : Rueda
# Jugador de Brasil: 11 : Hernandez
# Jugador de Brasil: 5 : Vasco
# Jugador de Brasil: 12 : Alfonso
# Jugador de Brasil: 19 : Alvarez
# Jugador de Brasil: 17 : Batanero
# Jugador de Brasil: 16 : Montaño
# Jugador de Brasil: 23 : Rodriguez
# Jugador de Brasil: 18 : Vargas
#
# Jugador de Argentina: 1 : Ramirez
# Jugador de Argentina: 10 : Messi
# Jugador de Argentina: 29 : Gutierrez
# Jugador de Argentina: 24 : Rodriguez
# Jugador de Argentina: 4 : Matiz
# Jugador de Argentina: 5 : Bernal
# Jugador de Argentina: 12 : Escobar
# Jugador de Argentina: 25 : Valderrama
# Jugador de Argentina: 45 : Velez
# Jugador de Argentina: 11 : Lozano
# Jugador de Argentina: 21 : Atehortua
# Jugador de Argentina: 90 : Torres
# Jugador de Argentina: 16 : Lopez
# Jugador de Argentina: 9 : Pedraza
# Jugador de Argentina: 14 : Bonilla
# Jugador de Argentina: 56 : Triviño
# Jugador de Argentina: 44 : Sacristan
#
# Jugador de Colombia: 1 : Rodriguez
# Jugador de Colombia: 23 : Ospina
# Jugador de Colombia: 11 : Diaz
# Jugador de Colombia: 9 : Sanchez
# Jugador de Colombia: 7 : Cuadrado
# Jugador de Colombia: 10 : Uribe
# Jugador de Colombia: 16 : Mina
# Jugador de Colombia: 21 : Triana
# Jugador de Colombia: 19 : Fernandez
# Jugador de Colombia: 22 : Ramirez
# Jugador de Colombia: 34 : Matiz
# Jugador de Colombia: 4 : Miranda
# Jugador de Colombia: 3 : Escobar
# Jugador de Colombia: 17 : Valderrama
# Jugador de Colombia: 2 : cubidez
# Jugador de Colombia: 6 : Ortega
# Jugador de Colombia: 56 : Olaya
#
# Jugador de Chile: 1 : Iniesta
# Jugador de Chile: 33 : Hernandez
# Jugador de Chile: 7 : Busquest
# Jugador de Chile: 9 : Ramos
# Jugador de Chile: 11 : Ronaldo
# Jugador de Chile: 10 : Alexis
# Jugador de Chile: 21 : Vidal
# Jugador de Chile: 19 : Vargas
# Jugador de Chile: 22 : Bravo
# Jugador de Chile: 66 : Valdivia
# Jugador de Chile: 101 : Jarrasco
# Jugador de Chile: 49 : Alvarez
# Jugador de Chile: 2 : Estupiñan
# Jugador de Chile: 5 : Cardona
# Jugador de Chile: 17 : Musleda
# Jugador de Chile: 77 : Garrincha
# Jugador de Chile: 18 : Khan
#
# Jugador de Ecuador: 1 : Llanos
# Jugador de Ecuador: 15 : Bernal
# Jugador de Ecuador: 6 : Kante
# Jugador de Ecuador: 7 : Pogba
# Jugador de Ecuador: 9 : Mbappe
# Jugador de Ecuador: 11 : Kounde
# Jugador de Ecuador: 10 : Pique
# Jugador de Ecuador: 33 : Torres
# Jugador de Ecuador: 19 : Acosta
# Jugador de Ecuador: 43 : Carrion
# Jugador de Ecuador: 88 : Di Maria
# Jugador de Ecuador: 23 : Haland
# Jugador de Ecuador: 54 : Cortes
# Jugador de Ecuador: 8 : Carpintero
# Jugador de Ecuador: 3 : Rengifo
# Jugador de Ecuador: 41 : Virguez
#
# Jugadores de Peru: 1 : Miranda
# Jugadores de Peru: 7 : Uribe
# Jugadores de Peru: 9 : Quijano
# Jugadores de Peru: 11 : Valencia
# Jugadores de Peru: 10 : Zarama
# Jugadores de Peru: 19 : Acero
# Jugadores de Peru: 21 : Bonilla
# Jugadores de Peru: 8 : Olaya
# Jugadores de Peru: 66 : Ramos
# Jugadores de Peru: 22 : Rosales
# Jugadores de Peru: 33 : Sanchez
# Jugadores de Peru: 17 : Gonzalez
# Jugadores de Peru: 18 : Dybala
# Jugadores de Peru: 5 : Ferrar
# Jugadores de Peru: 2 : Matiz
# Jugadores de Peru: 4 : Triana
# Jugadores de Peru: 77 : Montero
#
# ----------------------------------------------------------
# Posición de jugador de Brasil: 1 : Portero
# Posición de jugador de Brasil: 10 : Defensa
# Posición de jugador de Brasil: 15 : Defensa
# Posición de jugador de Brasil: 2 : Defensa
# Posición de jugador de Brasil: 8 : Defensa
# Posición de jugador de Brasil: 7 : Delantero
# Posición de jugador de Brasil: 9 : Delantero
# Posición de jugador de Brasil: 3 : Delantero
# Posición de jugador de Brasil: 4 : Mediocampista
# Posición de jugador de Brasil: 11 : Mediocampista
# Posición de jugador de Brasil: 5 : Mediocampista
# Posición de jugador de Brasil: 12 : Suplentes
# Posición de jugador de Brasil: 19 : Suplentes
# Posición de jugador de Brasil: 17 : Suplentes
# Posición de jugador de Brasil: 16 : Suplentes
# Posición de jugador de Brasil: 23 : Suplentes
# Posición de jugador de Brasil: 18 : Suplentes
#
# Posición de jugador de Argentina: 1 : Portero
# Posición de jugador de Argentina: 10 : Defensa
# Posición de jugador de Argentina: 29 : Defensa
# Posición de jugador de Argentina: 24 : Defensa
# Posición de jugador de Argentina: 4 : Defensa
# Posición de jugador de Argentina: 5 : Delantero
# Posición de jugador de Argentina: 12 : Delantero
# Posición de jugador de Argentina: 25 : Delantero
# Posición de jugador de Argentina: 45 : Mediocampista
# Posición de jugador de Argentina: 11 : Mediocampista
# Posición de jugador de Argentina: 21 : Mediocampista
# Posición de jugador de Argentina: 90 : Suplentes
# Posición de jugador de Argentina: 16 : Suplentes
# Posición de jugador de Argentina: 9 : Suplentes
# Posición de jugador de Argentina: 14 : Suplentes
# Posición de jugador de Argentina: 56 : Suplentes
# Posición de jugador de Argentina: 44 : Suplentes
#
# Posición de jugador de Colombia: 1 : Portero
# Posición de jugador de Colombia: 23 : Defensa
# Posición de jugador de Colombia: 11 : Defensa
# Posición de jugador de Colombia: 9 : Defensa
# Posición de jugador de Colombia: 7 : Defensa
# Posición de jugador de Colombia: 10 : Delantero
# Posición de jugador de Colombia: 16 : Delantero
# Posición de jugador de Colombia: 21 : Delantero
# Posición de jugador de Colombia: 19 : Mediocampista
# Posición de jugador de Colombia: 22 : Mediocampista
# Posición de jugador de Colombia: 34 : Mediocampista
# Posición de jugador de Colombia: 4 : Suplentes
# Posición de jugador de Colombia: 3 : Suplentes
# Posición de jugador de Colombia: 17 : Suplentes
# Posición de jugador de Colombia: 2 : Suplentes
# Posición de jugador de Colombia: 6 : Suplentes
# Posición de jugador de Colombia: 56 : Suplentes
#
# Posición de jugador de Chile: 1 : Portero
# Posición de jugador de Chile: 33 : Defensa
# Posición de jugador de Chile: 7 : Defensa
# Posición de jugador de Chile: 9 : Defensa
# Posición de jugador de Chile: 11 : Defensa
# Posición de jugador de Chile: 10 : Delantero
# Posición de jugador de Chile: 21 : Delantero
# Posición de jugador de Chile: 19 : Delantero
# Posición de jugador de Chile: 22 : Mediocampista
# Posición de jugador de Chile: 66 : Mediocampista
# Posición de jugador de Chile: 101 : Mediocampista
# Posición de jugador de Chile: 49 : Suplentes
# Posición de jugador de Chile: 2 : Suplentes
# Posición de jugador de Chile: 5 : Suplentes
# Posición de jugador de Chile: 17 : Suplentes
# Posición de jugador de Chile: 77 : Suplentes
# Posición de jugador de Chile: 18 : Suplentes
#
# Posición de jugador de Ecuador: 1 : Portero
# Posición de jugador de Ecuador: 15 : Defensa
# Posición de jugador de Ecuador: 6 : Defensa
# Posición de jugador de Ecuador: 7 : Defensa
# Posición de jugador de Ecuador: 9 : Defensa
# Posición de jugador de Ecuador: 11 : Delantero
# Posición de jugador de Ecuador: 10 : Delantero
# Posición de jugador de Ecuador: 33 : Delantero
# Posición de jugador de Ecuador: 19 : Mediocampista
# Posición de jugador de Ecuador: 43 : Mediocampista
# Posición de jugador de Ecuador: 88 : Mediocampista
# Posición de jugador de Ecuador: 23 : Suplentes
# Posición de jugador de Ecuador: 54 : Suplentes
# Posición de jugador de Ecuador: 8 : Suplentes
# Posición de jugador de Ecuador: 3 : Suplentes
# Posición de jugador de Ecuador: 41 : Suplentes
#
# Posición de jugador de Peru: 1 : Portero
# Posición de jugador de Peru: 7 : Defensa
# Posición de jugador de Peru: 9 : Defensa
# Posición de jugador de Peru: 11 : Defensa
# Posición de jugador de Peru: 10 : Defensa
# Posición de jugador de Peru: 19 : Delantero
# Posición de jugador de Peru: 21 : Delantero
# Posición de jugador de Peru: 8 : Delantero
# Posición de jugador de Peru: 66 : Mediocampista
# Posición de jugador de Peru: 22 : Mediocampista
# Posición de jugador de Peru: 33 : Mediocampista
# Posición de jugador de Peru: 17 : Suplentes
# Posición de jugador de Peru: 18 : Suplentes
# Posición de jugador de Peru: 5 : Suplentes
# Posición de jugador de Peru: 2 : Suplentes
# Posición de jugador de Peru: 4 : Suplentes
# Posición de jugador de Peru: 77 : Suplentes
#
# ----------------------------------------------------------
# Jugador Nueva convocatoria de Brasil 1 : Gomez
# Jugador Nueva convocatoria de Brasil 10 : Triana
# Jugador Nueva convocatoria de Brasil 15 : Fernandez
# Jugador Nueva convocatoria de Brasil 2 : Palacio
# Jugador Nueva convocatoria de Brasil 8 : Miranda
# Jugador Nueva convocatoria de Brasil 7 : Montero
# Jugador Nueva convocatoria de Brasil 9 : Benito
# Jugador Nueva convocatoria de Brasil 4 : Rueda
# Jugador Nueva convocatoria de Brasil 11 : Hernandez
# Jugador Nueva convocatoria de Brasil 5 : Vasco
# Jugador Nueva convocatoria de Brasil 12 : Alfonso
# Jugador Nueva convocatoria de Brasil 19 : Alvarez
# Jugador Nueva convocatoria de Brasil 17 : Batanero
# Jugador Nueva convocatoria de Brasil 16 : Montaño
# Jugador Nueva convocatoria de Brasil 23 : Rodriguez
# Jugador Nueva convocatoria de Brasil 18 : Vargas
# Jugador Nueva convocatoria de Brasil 27 : Gonzalez
#
# Jugador Nueva convocatoria de Argentina 1 : Ramirez
# Jugador Nueva convocatoria de Argentina 10 : Messi
# Jugador Nueva convocatoria de Argentina 29 : Gutierrez
# Jugador Nueva convocatoria de Argentina 24 : Rodriguez
# Jugador Nueva convocatoria de Argentina 4 : Matiz
# Jugador Nueva convocatoria de Argentina 5 : Bernal
# Jugador Nueva convocatoria de Argentina 12 : Escobar
# Jugador Nueva convocatoria de Argentina 25 : Valderrama
# Jugador Nueva convocatoria de Argentina 45 : Velez
# Jugador Nueva convocatoria de Argentina 11 : Lozano
# Jugador Nueva convocatoria de Argentina 21 : Atehortua
# Jugador Nueva convocatoria de Argentina 90 : Palacio
# Jugador Nueva convocatoria de Argentina 16 : Lopez
# Jugador Nueva convocatoria de Argentina 9 : Pedraza
# Jugador Nueva convocatoria de Argentina 14 : Bonilla
# Jugador Nueva convocatoria de Argentina 56 : Triviño
# Jugador Nueva convocatoria de Argentina 44 : Sacristan
#
# Jugador Nueva convocatoria de Colombia 1 : Rodriguez
# Jugador Nueva convocatoria de Colombia 23 : Ospina
# Jugador Nueva convocatoria de Colombia 9 : Sanchez
# Jugador Nueva convocatoria de Colombia 7 : Cuadrado
# Jugador Nueva convocatoria de Colombia 10 : Uribe
# Jugador Nueva convocatoria de Colombia 16 : Mina
# Jugador Nueva convocatoria de Colombia 21 : Triana
# Jugador Nueva convocatoria de Colombia 19 : Fernandez
# Jugador Nueva convocatoria de Colombia 22 : Ramirez
# Jugador Nueva convocatoria de Colombia 34 : Matiz
# Jugador Nueva convocatoria de Colombia 4 : Miranda
# Jugador Nueva convocatoria de Colombia 3 : Escobar
# Jugador Nueva convocatoria de Colombia 17 : Valderrama
# Jugador Nueva convocatoria de Colombia 2 : cubidez
# Jugador Nueva convocatoria de Colombia 6 : Ortega
# Jugador Nueva convocatoria de Colombia 56 : Olaya
# Jugador Nueva convocatoria de Colombia 105 : Jones
#
# Jugador Nueva convocatoria de Chile 1 : Iniesta
# Jugador Nueva convocatoria de Chile 33 : Hernandez
# Jugador Nueva convocatoria de Chile 7 : Busquest
# Jugador Nueva convocatoria de Chile 9 : Ramos
# Jugador Nueva convocatoria de Chile 11 : Ronaldo
# Jugador Nueva convocatoria de Chile 10 : Alexis
# Jugador Nueva convocatoria de Chile 21 : Vidal
# Jugador Nueva convocatoria de Chile 19 : Vargas
# Jugador Nueva convocatoria de Chile 22 : Bravo
# Jugador Nueva convocatoria de Chile 66 : Valdivia
# Jugador Nueva convocatoria de Chile 101 : Jarrasco
# Jugador Nueva convocatoria de Chile 49 : Alvarez
# Jugador Nueva convocatoria de Chile 2 : Estupiñan
# Jugador Nueva convocatoria de Chile 5 : Cardona
# Jugador Nueva convocatoria de Chile 17 : Musleda
# Jugador Nueva convocatoria de Chile 77 : Garrincha
# Jugador Nueva convocatoria de Chile 18 : Khan
# Jugador Nueva convocatoria de Chile 96 : Miranda
#
# Jugador Nueva convocatoria de Ecuador 1 : Llanos
# Jugador Nueva convocatoria de Ecuador 15 : Bernal
# Jugador Nueva convocatoria de Ecuador 6 : Kante
# Jugador Nueva convocatoria de Ecuador 7 : Pogba
# Jugador Nueva convocatoria de Ecuador 9 : Mbappe
# Jugador Nueva convocatoria de Ecuador 11 : Kounde
# Jugador Nueva convocatoria de Ecuador 10 : Pique
# Jugador Nueva convocatoria de Ecuador 33 : Torres
# Jugador Nueva convocatoria de Ecuador 19 : Acosta
# Jugador Nueva convocatoria de Ecuador 43 : Carrion
# Jugador Nueva convocatoria de Ecuador 88 : Di Maria
# Jugador Nueva convocatoria de Ecuador 23 : Haland
# Jugador Nueva convocatoria de Ecuador 54 : Cortes
# Jugador Nueva convocatoria de Ecuador 8 : Carpintero
# Jugador Nueva convocatoria de Ecuador 3 : Rengifo
# Jugador Nueva convocatoria de Ecuador 41 : Virguez
# Jugador Nueva convocatoria de Ecuador 89 : Serrato
#
# Jugador Nueva convocatoria de Peru 1 : Miranda
# Jugador Nueva convocatoria de Peru 7 : Uribe
# Jugador Nueva convocatoria de Peru 9 : Quijano
# Jugador Nueva convocatoria de Peru 10 : Zarama
# Jugador Nueva convocatoria de Peru 19 : Acero
# Jugador Nueva convocatoria de Peru 21 : Bonilla
# Jugador Nueva convocatoria de Peru 8 : Olaya
# Jugador Nueva convocatoria de Peru 66 : Ramos
# Jugador Nueva convocatoria de Peru 22 : Rosales
# Jugador Nueva convocatoria de Peru 33 : Sanchez
# Jugador Nueva convocatoria de Peru 17 : Gonzalez
# Jugador Nueva convocatoria de Peru 18 : Dybala
# Jugador Nueva convocatoria de Peru 5 : Ferrar
# Jugador Nueva convocatoria de Peru 2 : Matiz
# Jugador Nueva convocatoria de Peru 4 : Triana
# Jugador Nueva convocatoria de Peru 77 : Montero
# Jugador Nueva convocatoria de Peru 48 : Perez
#
# ----------------------------------------------------------
# Capitan de Brasil es:
# Gomez
# Capitan de Argentina es:
# Messi
# Capitan de Colombia es:
# Uribe
# Capitan de Chile es:
# Busquest
# Capitan de Ecuador es:
# Pique
# Capitan de Peru es:
# Zarama
# ----------------------------------------------------------
# ========== Ronda 1 ==========
# GRUPO A -> Argentina 0 - 2 Chile
# GRUPO A -> Colombia 3 - 3 Equipo invitado
# GRUPO B -> Brasil 0 - 2 Peru
# GRUPO B -> Ecuador 2 - 4 Equipo inivitado
#
# ========== Ronda 2 ==========
# GRUPO A -> Chile 0 - 2 Colombia
# GRUPO A -> Equipo invitado 4 - 0 Argentina
# GRUPO B -> Peru 1 - 3 Ecuador
# GRUPO B -> Equipo inivitado 4 - 1 Brasil
#
# ========== Ronda 3 ==========
# GRUPO A -> Argentina 3 - 2 Colombia
# GRUPO A -> Equipo invitado 2 - 1 Chile
# GRUPO B -> Brasil 0 - 1 Ecuador
# GRUPO B -> Equipo inivitado 2 - 2 Peru
#
# ========== RESULTADOS ==========
# Argentina    -> PTS: 3 | GF: 3 | GC: 8
# Chile        -> PTS: 3 | GF: 3 | GC: 4
# Colombia     -> PTS: 4 | GF: 7 | GC: 6
# Equipo invitado -> PTS: 7 | GF: 9 | GC: 4
# Brasil       -> PTS: 0 | GF: 1 | GC: 7
# Peru         -> PTS: 4 | GF: 5 | GC: 5
# Ecuador      -> PTS: 6 | GF: 6 | GC: 5
# Equipo inivitado -> PTS: 7 | GF: 10 | GC: 5
